# %%
# !pip install pygad==2.3.0
# Out:
# Collecting pygad==2.3.0
#   Downloading pygad-2.3.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pygad==2.3.0) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pygad==2.3.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pygad==2.3.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pygad==2.3.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pygad==2.3.0) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pygad==2.3.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pygad==2.3.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pygad==2.3.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pygad==2.3.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pygad==2.3.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pygad==2.3.0) (1.16.0)
# Installing collected packages: pygad
# Successfully installed pygad-2.3.0

# %%
import pygad
import numpy

# %%
print(pygad.__version__)
# Out:
# 2.3.0

# %%
def fitness_func(solution, solution_idx):
    output = numpy.sum(solution*function_inputs)
    fitness = 1.0 / numpy.abs(output - desired_output)
    return fitness

# %%
function_inputs = [4,-2,3.5,5,-11,-4.7]
desired_output = 44

fitness_function = fitness_func

num_generations = 100
num_parents_mating = 7

sol_per_pop = 50
num_genes = len(function_inputs)

init_range_low = -2
init_range_high = 5

parent_selection_type = "sss"
keep_parents = 7

crossover_type = "single_point"

mutation_type = "random"
mutation_percent_genes = 10
last_fitness = 0

# %%
def callback_generation2(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=(ga_instance.best_solution()[1] - last_fitness)))
    last_fitness = ga_instance.best_solution()[1]

# %%
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating,
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop,
                       num_genes=num_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       keep_parents=keep_parents,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes,
                       callback_generation=callback_generation2)

# %%
ga_instance.run()

ga_instance.plot_result()

solution, solution_fitness, solution_idx = ga_instance.best_solution()
# Out:
# Generation = 1
# Fitness    = 0.616962023344728
# Change     = 0.616962023344728
# Generation = 2
# Fitness    = 0.616962023344728
# Change     = 0.0
# Generation = 3
# Fitness    = 8.416393491930538
# Change     = 7.79943146858581
# Generation = 4
# Fitness    = 14.06610377612853
# Change     = 5.649710284197992
# Generation = 5
# Fitness    = 14.06610377612853
# Change     = 0.0
# Generation = 6
# Fitness    = 27.372164450389345
# Change     = 13.306060674260815
# Generation = 7
# Fitness    = 28.721783295253626
# Change     = 1.3496188448642812
# Generation = 8
# Fitness    = 28.721783295253626
# Change     = 0.0
# Generation = 9
# Fitness    = 28.721783295253626
# Change     = 0.0
# Generation = 10
# Fitness    = 270.43616568849257
# Change     = 241.71438239323894
# Generation = 11
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 12
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 13
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 14
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 15
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 16
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 17
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 18
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 19
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 20
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 21
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 22
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 23
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 24
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 25
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 26
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 27
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 28
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 29
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 30
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 31
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 32
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 33
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 34
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 35
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 36
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 37
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 38
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 39
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 40
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 41
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 42
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 43
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 44
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 45
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 46
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 47
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 48
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 49
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 50
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 51
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 52
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 53
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 54
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 55
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 56
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 57
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 58
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 59
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 60
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 61
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 62
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 63
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 64
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 65
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 66
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 67
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 68
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 69
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 70
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 71
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 72
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 73
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 74
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 75
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 76
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 77
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 78
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 79
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 80
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 81
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 82
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 83
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 84
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 85
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 86
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 87
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 88
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 89
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 90
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 91
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 92
# Fitness    = 270.43616568849257
# Change     = 0.0
# Generation = 93
# Fitness    = 423.62724947579943
# Change     = 153.19108378730687
# Generation = 94
# Fitness    = 423.62724947579943
# Change     = 0.0
# Generation = 95
# Fitness    = 423.62724947579943
# Change     = 0.0
# Generation = 96
# Fitness    = 423.62724947579943
# Change     = 0.0
# Generation = 97
# Fitness    = 423.62724947579943
# Change     = 0.0
# Generation = 98
# Fitness    = 423.62724947579943
# Change     = 0.0
# Generation = 99
# Fitness    = 423.62724947579943
# Change     = 0.0
# Generation = 100
# Fitness    = 1227.1907693370908
# Change     = 803.5635198612914

# %%
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

prediction = numpy.sum(numpy.array(function_inputs)*solution)
print("Predicted output based on the best solution : {prediction}".format(prediction=prediction))

if ga_instance.best_solution_generation != -1:
    print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))
# Out:
# Parameters of the best solution : [ 2.68718722 -0.35390928  4.74587711  4.2261668  -0.33278174  1.88462885]
# Fitness value of the best solution = 1227.1907693370908
# Index of the best solution : 29
# Predicted output based on the best solution : 44.00081486923222
# Best fitness value reached after 93 generations.
